# %%
import pandas as pd

# %%
df1 = pd.read_csv('7-concat_data1.csv')

# %%
df1
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1    Finance
# 1            2   Emp_2  Marketing
# 2            3   Emp_3         HR
# 3            4   Emp_4    Finance
# 4            5   Emp_5    Finance
# 5            6   Emp_6  Marketing
# 6            7   Emp_7         HR
# 7            8   Emp_8         HR
# 8            9   Emp_9    Finance
# 9           10  Emp_10         IT

# %%
df2 = pd.read_csv('7-concat_data2.csv')

# %%
df2
# Out:
#    Employee_ID    Name Department
# 0           11  Emp_11    Finance
# 1           12  Emp_12    Finance
# 2           13  Emp_13    Finance
# 3           14  Emp_14    Finance
# 4           15  Emp_15  Marketing
# 5           16  Emp_16         HR
# 6           17  Emp_17  Marketing
# 7           18  Emp_18  Marketing
# 8           19  Emp_19  Marketing
# 9           20  Emp_20    Finance

# %%
# concat metoduyla birleştirme yapılır

# %%
df_concat = pd.concat([df1,df2], ignore_index = True)

# %%
df_concat
# Out:
#     Employee_ID    Name Department
# 0             1   Emp_1    Finance
# 1             2   Emp_2  Marketing
# 2             3   Emp_3         HR
# 3             4   Emp_4    Finance
# 4             5   Emp_5    Finance
# 5             6   Emp_6  Marketing
# 6             7   Emp_7         HR
# 7             8   Emp_8         HR
# 8             9   Emp_9    Finance
# 9            10  Emp_10         IT
# 10           11  Emp_11    Finance
# 11           12  Emp_12    Finance
# 12           13  Emp_13    Finance
# 13           14  Emp_14    Finance
# 14           15  Emp_15  Marketing
# 15           16  Emp_16         HR
# 16           17  Emp_17  Marketing
# 17           18  Emp_18  Marketing
# 18           19  Emp_19  Marketing
# 19           20  Emp_20    Finance

# %%
#merge

# %%
df_merge1 = pd.read_csv("7-merge_data1.csv")

# %%
df_merge1
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1         IT
# 1            2   Emp_2         HR
# 2            3   Emp_3         IT
# 3            4   Emp_4  Marketing
# 4            5   Emp_5  Marketing
# 5            6   Emp_6         IT
# 6            7   Emp_7         IT
# 7            8   Emp_8         IT
# 8            9   Emp_9  Marketing
# 9           10  Emp_10  Marketing

# %%
df_merge2 = pd.read_csv("7-merge_data2.csv")

# %%
df_merge2
# Out:
#    Employee_ID  Salary  Experience
# 0            5   55658           3
# 1            1  114478           5
# 2           12   48431          19
# 3           10   32747           7
# 4            6   89150           9
# 5           13   95725           7
# 6            9   65773           4
# 7           11   86886          18

# %%
# merge - outer join

# %%
df_merge_outer = pd.merge(df_merge1, df_merge2, on="Employee_ID", how = "outer")

# %%
df_merge_outer
# Out:
#     Employee_ID    Name Department    Salary  Experience
# 0             1   Emp_1         IT  114478.0         5.0
# 1             2   Emp_2         HR       NaN         NaN
# 2             3   Emp_3         IT       NaN         NaN
# 3             4   Emp_4  Marketing       NaN         NaN
# 4             5   Emp_5  Marketing   55658.0         3.0
# 5             6   Emp_6         IT   89150.0         9.0
# 6             7   Emp_7         IT       NaN         NaN
# 7             8   Emp_8         IT       NaN         NaN
# 8             9   Emp_9  Marketing   65773.0         4.0
# 9            10  Emp_10  Marketing   32747.0         7.0
# 10           11     NaN        NaN   86886.0        18.0
# 11           12     NaN        NaN   48431.0        19.0
# 12           13     NaN        NaN   95725.0         7.0

# %%
# merge - left join

# %%
df_merge_left = pd.merge(df_merge1, df_merge2, on = 'Employee_ID', how = 'left')

# %%
df_merge_left
# Out:
#    Employee_ID    Name Department    Salary  Experience
# 0            1   Emp_1         IT  114478.0         5.0
# 1            2   Emp_2         HR       NaN         NaN
# 2            3   Emp_3         IT       NaN         NaN
# 3            4   Emp_4  Marketing       NaN         NaN
# 4            5   Emp_5  Marketing   55658.0         3.0
# 5            6   Emp_6         IT   89150.0         9.0
# 6            7   Emp_7         IT       NaN         NaN
# 7            8   Emp_8         IT       NaN         NaN
# 8            9   Emp_9  Marketing   65773.0         4.0
# 9           10  Emp_10  Marketing   32747.0         7.0

# %%
# merge - right join

# %%
df_merge_right = pd.merge(df_merge1, df_merge2, on = 'Employee_ID', how = 'right')

# %%
df_merge_right
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            5   Emp_5  Marketing   55658           3
# 1            1   Emp_1         IT  114478           5
# 2           12     NaN        NaN   48431          19
# 3           10  Emp_10  Marketing   32747           7
# 4            6   Emp_6         IT   89150           9
# 5           13     NaN        NaN   95725           7
# 6            9   Emp_9  Marketing   65773           4
# 7           11     NaN        NaN   86886          18

# %%
# merge - inner join

# %%
df_merged = pd.merge(df_merge1, df_merge2, on="Employee_ID", how="inner")

# %%
df_merged
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            1   Emp_1         IT  114478           5
# 1            5   Emp_5  Marketing   55658           3
# 2            6   Emp_6         IT   89150           9
# 3            9   Emp_9  Marketing   65773           4
# 4           10  Emp_10  Marketing   32747           7

# %%
#dataframesapply

# %%
df = pd.read_csv('8-apply_function_data.csv')

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    Employee_ID   Name Department  Salary  Experience  Performance_Score
# 0            1  Emp_1  Marketing   82251           6                  5
# 1            2  Emp_2      Sales   52662          24                  3
# 2            3  Emp_3    Finance   38392           5                  3
# 3            4  Emp_4      Sales   60535          20                  3
# 4            5  Emp_5      Sales  108603           2                  2

# %%
df.tail()
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3

# %%
df.describe()
# Out:
#        Employee_ID         Salary  Experience  Performance_Score
# count   100.000000     100.000000  100.000000          100.00000
# mean     50.500000   77508.090000   12.090000            3.03000
# std      29.011492   26083.327596    7.543939            1.41746
# min       1.000000   30206.000000    1.000000            1.00000
# 25%      25.750000   54347.500000    5.000000            2.00000
# 50%      50.500000   80932.000000   12.000000            3.00000
# 75%      75.250000   97620.500000   19.000000            4.00000
# max     100.000000  119474.000000   24.000000            5.00000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        100 non-null    int64
#  1   Name               100 non-null    str
#  2   Department         100 non-null    str
#  3   Salary             100 non-null    int64
#  4   Experience         100 non-null    int64
#  5   Performance_Score  100 non-null    int64
# dtypes: int64(4), str(2)
# memory usage: 4.8 KB

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Department', 'Salary', 'Experience',
#        'Performance_Score'],
#       dtype='str')

# %%
df[1:20]
# Out:
#     Employee_ID    Name Department  Salary  Experience  Performance_Score
# 1             2   Emp_2      Sales   52662          24                  3
# 2             3   Emp_3    Finance   38392           5                  3
# 3             4   Emp_4      Sales   60535          20                  3
# 4             5   Emp_5      Sales  108603           2                  2
# 5             6   Emp_6         IT   82256           6                  5
# 6             7   Emp_7    Finance  119135          22                  1
# 7             8   Emp_8    Finance   65222          11                  4
# 8             9   Emp_9    Finance  107373          16                  1
# 9            10  Emp_10      Sales  109575          16                  5
# 10           11  Emp_11  Marketing  114651           1                  4
# 11           12  Emp_12    Finance   93335           9                  5
# 12           13  Emp_13      Sales   40965           6                  3
# ...

# %%
def salary_category(salary):
    if salary < 50000:
        return "Low"
    elif 50000 <= salary < 80000:
        return "Meduim"
    else:
        return "High"

# %%
df["Salary"].apply(salary_category)
# Out:
# 0       High
# 1     Meduim
# 2        Low
# 3     Meduim
# 4       High
#        ...
# 95      High
# 96      High
# 97      High
# 98       Low
# 99    Meduim
# Name: Salary, Length: 100, dtype: str

# %%
df["Salary_Category"] = df["Salary"].apply(salary_category)

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category
# 0             High
# 1           Meduim
# ...

# %%
def adjust_performance(experience):
    if experience > 10:
        return 1
    else: 
        return 0

# %%
df["Adjusted"]=df["Experience"].apply(adjust_performance)

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category  Adjusted
# 0             High         0
# ...

# %%
df["New_Score"] = df["Performance_Score"] + df["Adjusted"]

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category  Adjusted  New_Score
# ...

# %%
def adjust_new(row):
    if row["Experience"] > 10:
        return row["Performance_Score"] + 1
    else:
        return row["Performance_Score"]

# %%
df["Adjusted_Score"] = df.apply(adjust_new, axis = 1)

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
# ...

# %%
df["Formatted_Name"] = df["Name"].apply(lambda x:x.replace("_"," "))

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
# ...

# %%
df = df.drop('Adjusted_Score', axis=1)

# %%
df = df.drop('Formatted_Name',axis=1)

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category  Adjusted  New_Score
# ...

# %%
df['Salary'] = df['Salary'] + 10

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82261           6                  5
# 1             2    Emp_2      Sales   52672          24                  3
# 2             3    Emp_3    Finance   38402           5                  3
# 3             4    Emp_4      Sales   60545          20                  3
# 4             5    Emp_5      Sales  108613           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93744          19                  4
# 96           97   Emp_97      Sales  100477          22                  2
# 97           98   Emp_98         IT   82672          23                  3
# 98           99   Emp_99         IT   42698          22                  1
# 99          100  Emp_100         HR   55352          14                  3
#
#    Salary_Category  Adjusted  New_Score
# ...

# %%
df.loc[df['Department'] == 'Sales','Salary'] +=10

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82261           6                  5
# 1             2    Emp_2      Sales   52682          24                  3
# 2             3    Emp_3    Finance   38402           5                  3
# 3             4    Emp_4      Sales   60555          20                  3
# 4             5    Emp_5      Sales  108623           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93744          19                  4
# 96           97   Emp_97      Sales  100487          22                  2
# 97           98   Emp_98         IT   82672          23                  3
# 98           99   Emp_99         IT   42698          22                  1
# 99          100  Emp_100         HR   55352          14                  3
#
#    Salary_Category  Adjusted  New_Score
# ...

# %%
df[(df['Salary'] > 50000) & (df['Department'] == 'Sales')]
# Out:
#     Employee_ID    Name Department  Salary  Experience  Performance_Score  \
# 1             2   Emp_2      Sales   52682          24                  3
# 3             4   Emp_4      Sales   60555          20                  3
# 4             5   Emp_5      Sales  108623           2                  2
# 9            10  Emp_10      Sales  109595          16                  5
# 17           18  Emp_18      Sales   57286          19                  4
# 35           36  Emp_36      Sales   85840           7                  3
# 37           38  Emp_38      Sales  111754          16                  1
# 47           48  Emp_48      Sales   78945           9                  1
# 71           72  Emp_72      Sales   91107          18                  1
# 72           73  Emp_73      Sales   98860          14                  2
# 74           75  Emp_75      Sales   81025           2                  2
# 80           81  Emp_81      Sales   95338           1                  4
# ...

# %%
df.loc[df['Department'] == 'Sales', 'Salary'] -= 25000

# %%
df[df['Salary'] < 0]
# Out:
#     Employee_ID    Name Department  Salary  Experience  Performance_Score  \
# 12           13  Emp_13      Sales   -9015           6                  3
# 21           22  Emp_22      Sales  -19774           7                  3
# 53           54  Emp_54      Sales   -4273           3                  2
# 62           63  Emp_63      Sales  -10506          17                  5
#
#    Salary_Category  Adjusted  New_Score
# 12             Low         0          3
# 21             Low         0          3
# 53             Low         0          2
# 62             Low         1          6

# %%
df[df['Department'] == 'Sales','Salary'] +=50000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0     False
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 95    False
# 96     True
# 97    False
# 98    False
# 99    False
# Name: Department, Length: 100, dtype: bool, 'Salary')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[117], line 1
# ...
