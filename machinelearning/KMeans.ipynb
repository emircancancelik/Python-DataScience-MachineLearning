# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("26-customer_data.csv")

# %%
df.tail()
# Out:
#       Annual_Income  Spending_Score
# 1494      -4.937560      -10.019685
# 1495      -7.493203       -5.602109
# 1496       6.253449       -5.247933
# 1497       6.684590       -6.017490
# 1498      -3.067648       -8.511785

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Annual_Income   1499 non-null   float64
#  1   Spending_Score  1499 non-null   float64
# dtypes: float64(2)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#        Annual_Income  Spending_Score
# count    1499.000000     1499.000000
# mean       -1.858568       -6.633932
# std         6.895124        2.608376
# min       -10.709274      -12.978282
# 25%        -7.316109       -9.264460
# 50%        -5.237149       -5.940883
# 75%         6.995162       -4.513904
# max        10.056333       -1.820017

# %%
sns.scatterplot(data=df, x="Annual_Income", y="Spending_Score")
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Spending_Score'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(df, test_size = 0.2, random_state=15)

# %%
X_train
# Out:
#       Annual_Income  Spending_Score
# 258        7.809992       -5.031123
# 195        7.769519       -6.059915
# 817       -8.529586       -4.853877
# 820       -5.765759       -9.822013
# 716       -7.932068       -4.882406
# ...             ...             ...
# 667       -6.734875       -5.107626
# 156       -8.236823       -3.127431
# 384       -7.744180       -3.563590
# 645       -6.151325       -9.263209
# 1480      -8.413924       -5.354832
#
# [1199 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.cluster import KMeans

# %%
#elbos method
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X_train_scaled)
    wcss.append(kmeans.inertia_)

# %%
kmeans.labels_
# Out:
# array([1, 5, 9, ..., 3, 7, 0], shape=(1199,), dtype=int32)

# %%
kmeans.inertia_
# Out:
# 4.108551924514915

# %%
wcss
# Out:
# [196.9206878471016,
#  68.44836482219306,
#  11.697030239519934,
#  9.601859952372997,
#  7.88339569159208,
#  6.089460293684871,
#  6.885263414857599,
#  4.995306616393396,
#  4.611928200542661,
#  4.108551924514915]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=3)

# %%
kmeans.fit(X_train_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
y_pred = kmeans.predict(X_test_scaled)

# %%
sns.scatterplot(data=pd.DataFrame(X_test_scaled, columns = X_test.columns), x="Annual_Income", y="Spending_Score", hue=y_pred)
plt.show()

# %%
# %pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.14.2 in /opt/homebrew/lib/python3.14/site-packages (from kneed) (2.4.2)
# Requirement already satisfied: scipy>=1.0.0 in /opt/homebrew/lib/python3.14/site-packages (from kneed) (1.17.0)
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from kneed import KneeLocator

# %%
kl = KneeLocator(range(1,11) , wcss, curve="convex", direction="decreasing")

# %%
kl.elbow
# Out:
# np.int64(3)

# %%
#silhouate score

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X_train_scaled)
    score = silhouette_score(X_train_scaled, kmeans.labels_)
    silhouette.append(score)

# %%
silhouette
# Out:
# [0.6538372460771634,
#  0.7856941696336582,
#  0.6533184470562033,
#  0.537552874672021,
#  0.39427592370493997,
#  0.3737320277672262,
#  0.3605999078375695,
#  0.3647021219216486,
#  0.36469298312492066]

# %%
plt.plot(range(2,11),silhouette)
plt.xticks(range(2,11))
plt.xlabel("number of clusters")
plt.ylabel("silhouette coefficients")
plt.show()
