# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("9-seismic_activity_svm.csv")

# %%
df.head()
# Out:
#    underground_wave_energy  vibration_axis_variation  seismic_event_detected
# 0                 9.539392                 -3.000000                       0
# 1                 9.558241                 -2.939394                       0
# 2                 9.576669                 -2.878788                       0
# 3                 9.594678                 -2.818182                       0
# 4                 9.612272                 -2.757576                       0

# %%
df.tail()
# Out:
#      underground_wave_energy  vibration_axis_variation  seismic_event_detected
# 395                -4.170824                 -2.757576                       1
# 396                -4.130115                 -2.818182                       1
# 397                -4.088102                 -2.878788                       1
# 398                -4.044745                 -2.939394                       1
# 399                -4.000000                 -3.000000                       1

# %%
df.describe()
# Out:
#        underground_wave_energy  vibration_axis_variation  \
# count               400.000000              4.000000e+02
# mean                  0.000000              8.881784e-18
# std                   7.719350              1.751650e+00
# min                  -9.999954             -3.000000e+00
# 25%                  -6.134779             -1.500000e+00
# 50%                   0.000000              0.000000e+00
# 75%                   6.134779              1.500000e+00
# max                   9.999954              3.000000e+00
#
#        seismic_event_detected
# count              400.000000
# mean                 0.500000
# std                  0.500626
# min                  0.000000
# 25%                  0.000000
# 50%                  0.500000
# 75%                  1.000000
# max                  1.000000

# %%
df["seismic_event_detected"].value_counts()
# Out:
# seismic_event_detected
# 0    200
# 1    200
# Name: count, dtype: int64

# %%
sns.scatterplot(x=df["underground_wave_energy"], y=df["vibration_axis_variation"], hue=df["seismic_event_detected"])
plt.show()

# %%
#manual rbf kernel

# %%
df.columns
# Out:
# Index(['underground_wave_energy', 'vibration_axis_variation',
#        'seismic_event_detected'],
#       dtype='object')

# %%
df["underground_wave_energy ** 2"] = df["underground_wave_energy"] ** 2
df["vibration_axis_variation ** 2"] = df["vibration_axis_variation"] ** 2
df["underground_wave_energy * vibration_axis_variation"] = (df["underground_wave_energy"] * df["vibration_axis_variation"])

# %%
df.head()
# Out:
#    underground_wave_energy  vibration_axis_variation  seismic_event_detected  \
# 0                 9.539392                 -3.000000                       0
# 1                 9.558241                 -2.939394                       0
# 2                 9.576669                 -2.878788                       0
# 3                 9.594678                 -2.818182                       0
# 4                 9.612272                 -2.757576                       0
#
#    underground_wave_energy ** 2  vibration_axis_variation ** 2  \
# 0                     91.000000                       9.000000
# 1                     91.359963                       8.640037
# 2                     91.712580                       8.287420
# 3                     92.057851                       7.942149
# 4                     92.395776                       7.604224
#
#    underground_wave_energy * vibration_axis_variation
# 0                                         -28.618176
# 1                                         -28.095434
# 2                                         -27.569197
# 3                                         -27.039548
# 4                                         -26.506569

# %%
X=df.drop("seismic_event_detected", axis=1)
y=df["seismic_event_detected"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=15)

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from plotly) (2.17.0)
# Requirement already satisfied: packaging in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(df, x="underground_wave_energy ** 2", y="vibration_axis_variation ** 2", 
                    z="underground_wave_energy * vibration_axis_variation",
                    color = "seismic_event_detected")
fig.show()

# %%
param_grid = {
    "C": [0.1, 1, 10, 100, 1000],
    "kernel": ["rbf"],
    "gamma" : ["scale","auto"]
}

# %%
grid = GridSearchCV(estimator=SVC(), param_grid = param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': ['scale', 'auto'], 'kernel': ['rbf']})

# %%
linear = SVC(kernel="linear")
linear.fit(X_train, y_train)
y_pred8 = grid.predict(X_test)
print(classification_report(y_pred8, y_test))
print(confusion_matrix(y_pred8, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00        52
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# [[48  0]
#  [ 0 52]]

# %%
#automatic rbf

# %%
df = pd.read_csv("9-seismic_activity_svm.csv")

# %%
X=df.drop("seismic_event_detected", axis=1)
y = df["seismic_event_detected"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 15)

# %%
rbf = SVC(kernel="linear")
linear.fit(X_train, y_train)
y_pred9 = grid.predict(X_test)
print(classification_report(y_pred9, y_test))
print(confusion_matrix(y_pred9, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00        52
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# [[48  0]
#  [ 0 52]]
