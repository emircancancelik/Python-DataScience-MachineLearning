# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("18-concrete_data.csv")

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
df["Blast_Furnace_Slag"] = df.drop(["Blast Furnace Slag"],axis=1)
df["Fine_Aggregate"] = df["Fine Aggregate"]
df["Coarse_Aggregate"] = df["Coarse Aggregate"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/h5/swlzny612n16xym3ymfjfzsh0000gn/T/ipykernel_13368/4081697974.py in ?()
# ----> 1 df["Blast_Furnace_Slag"] = df.drop(["Blast Furnace Slag"],axis=1)
#       2 df["Fine_Aggregate"] = df["Fine Aggregate"]
#       3 df["Coarse_Aggregate"] = df["Coarse Aggregate"]
#
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4308             self._setitem_frame(key, value)
#    4309         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4310             self._setitem_array(key, value)
#    4311         elif isinstance(value, DataFrame):
# -> 4312             self._set_item_frame_value(key, value)
#    4313         elif (
#    4314             is_list_like(value)
#    4315             and not self.columns.is_unique
#
# ...

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength',
#        'Blast_Furnace_Slag', 'Fine_Aggregate', 'Coarse_Aggregate'],
#       dtype='object')

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength  Blast_Furnace_Slag  \
# 0            1040.0           676.0   28     79.99                 0.0
# 1            1055.0           676.0   28     61.89                 0.0
# 2             932.0           594.0  270     40.27               142.5
# 3             932.0           594.0  365     41.05               142.5
# 4             978.4           825.5  360     44.30               132.4
#
#    Fine_Aggregate  Coarse_Aggregate
# 0           676.0            1040.0
# 1           676.0            1055.0
# 2           594.0             932.0
# ...
