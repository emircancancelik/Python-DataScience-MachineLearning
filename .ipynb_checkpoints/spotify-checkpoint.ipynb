# %%
# %pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-7.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from spotipy) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from spotipy) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from requests>=2.25.0->spotipy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages (from requests>=2.25.0->spotipy) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.14/site-packages (from requests>=2.25.0->spotipy) (2026.1.4)
# Downloading spotipy-2.25.2-py3-none-any.whl (31 kB)
# Downloading redis-7.2.0-py3-none-any.whl (394 kB)
# Installing collected packages: redis, spotipy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [spotipy]
# Successfully installed redis-7.2.0 spotipy-2.25.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# 1. KİMLİK BİLGİLERİ
client_id = '568c2b777f644efdb8635856b9ebbd93'
client_secret = '46c38d7c909a48d2b4c4154bdb882075'
# PORTU 9000 YAPTIK (Dashboard'da da değiştir!)
redirect_uri = 'http://127.0.0.1:9000/callback' 
# SADECE ID KISMINI YAZDIK
playlist_id = '37i9dQZF1EJe6Wv35251' 

# 2. SPOTIFY BAĞLANTISI (open_browser=False manuel giriş sağlar)
auth_manager = SpotifyOAuth(client_id=client_id,
                            client_secret=client_secret,
                            redirect_uri=redirect_uri,
                            scope="playlist-read-private",
                            open_browser=False)

sp = spotipy.Spotify(auth_manager=auth_manager)

# 3. VERİ ÇEKME
results = sp.playlist_items(playlist_id)
tracks = results['items']

data = []
for item in tracks:
    track = item['track']
    if track:
        data.append({
            'id': track['id'],
            'name': track['name'],
            'artist': track['artists'][0]['name'],
            'added_by': item['added_by']['id']
        })

df = pd.DataFrame(data)

# 4. TEKNİK ÖZELLİKLERİ EKLEME
track_ids = df['id'].tolist()
audio_features = sp.audio_features(track_ids)
features_df = pd.DataFrame(audio_features)

final_df = pd.merge(df, features_df[['id', 'danceability', 'energy', 'valence', 'tempo']], on='id')

print("Veriler başarıyla çekildi!")
print(final_df.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 20
#      14 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
#      15                                                client_secret=client_secret,
#      16                                                redirect_uri=redirect_uri,
#      17                                                scope="playlist-read-private"))
#      19 # 3. VERİ ÇEKME
# ---> 20 results = sp.playlist_items(playlist_id)
#      21 tracks = results['items']
#      23 data = []
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/client.py:732, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     720 """ Get full details of the tracks and episodes of a playlist.
#     721
#     722     Parameters:
#    (...)    729                              valid types are: track and episode
#     730 """
#     731 plid = self._get_id("playlist", playlist_id)
# --> 732 return self._get(
#     733     f"playlists/{plid}/tracks",
#     734     limit=limit,
#     735     offset=offset,
#     736     fields=fields,
#     737     market=market,
#     738     additional_types=",".join(additional_types)
#     739 )
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     318 if args:
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/oauth2.py:513, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     506             token_info = self.refresh_access_token(
#     507                 token_info["refresh_token"]
#     508             )
#     509         return token_info if as_dict else token_info["access_token"]
#     511 payload = {
#     512     "redirect_uri": self.redirect_uri,
# --> 513     "code": code or self.get_auth_response(),
#     514     "grant_type": "authorization_code",
#     515 }
#     516 if self.scope:
#     517     payload["scope"] = self.scope
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/oauth2.py:469, in SpotifyOAuth.get_auth_response(self, open_browser)
#     462 if (
#     463         open_browser
#     464         and redirect_host in ("127.0.0.1", "localhost")
#     465         and redirect_info.scheme == "http"
#     466 ):
#     467     # Only start a local http server if a port is specified
#     468     if redirect_port:
# --> 469         return self._get_auth_response_local_server(redirect_port)
#     470     else:
#     471         logger.warning(f'Using `{redirect_host}` as redirect URI without a port. '
#     472                        f'Specify a port (e.g. `{redirect_host}:8080`) to allow '
#     473                        'automatic retrieval of authentication code '
#     474                        'instead of having to copy and paste '
#     475                        'the URL your browser is redirected to.')
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/oauth2.py:425, in SpotifyOAuth._get_auth_response_local_server(self, redirect_port)
#     424 def _get_auth_response_local_server(self, redirect_port):
# --> 425     server = start_local_http_server(redirect_port)
#     426     self._open_auth_url()
#     427     server.handle_request()
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/spotipy/oauth2.py:1285, in start_local_http_server(port, handler)
#    1284 def start_local_http_server(port, handler=RequestHandler):
# -> 1285     server = HTTPServer(("127.0.0.1", port), handler)
#    1286     server.allow_reuse_address = True
#    1287     server.auth_code = None
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socketserver.py:457, in TCPServer.__init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     455 if bind_and_activate:
#     456     try:
# --> 457         self.server_bind()
#     458         self.server_activate()
#     459     except:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/server.py:148, in HTTPServer.server_bind(self)
#     146 def server_bind(self):
#     147     """Override server_bind to store the server name."""
# --> 148     socketserver.TCPServer.server_bind(self)
#     149     host, port = self.server_address[:2]
#     150     self.server_name = socket.getfqdn(host)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socketserver.py:478, in TCPServer.server_bind(self)
#     473 if (
#     474     self.allow_reuse_port and hasattr(socket, "SO_REUSEPORT")
#     475     and self.address_family in (socket.AF_INET, socket.AF_INET6)
#     476 ):
#     477     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 478 self.socket.bind(self.server_address)
#     479 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 48] Address already in use

# %%
sns.scatterplot(data=final_df, x='energy', y='valence', hue='added_by')
plt.title('Spotify Blend: Enerji vs Mutluluk Analizi')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.scatterplot(data=final_df, x='energy', y='valence', hue='added_by')
#       2 plt.title('Spotify Blend: Enerji vs Mutluluk Analizi')
#       3 plt.show()
#
# NameError: name 'final_df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 1. Şarkı ID'lerini bir listeye alalım
# ----> 2 track_ids = df['id'].tolist()
#       4 # 2. Bu ID'ler için teknik özellikleri çekelim
#       5 audio_features = sp.audio_features(track_ids)
#
# NameError: name 'df' is not defined
